# %% [markdown]
# this notebook, i've attempted to take in all the 6 data vectors (ax,ay,az,gx,gy and gz) and fitted it into a 1D CNN and the output of that is fit into a simple DNN.

# %%
# Imports

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, utils

# For reproducibility
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("Libraries loaded. TensorFlow version:", tf.__version__)
# Out:
# Libraries loaded. TensorFlow version: 2.19.0

# %%
# User-configurable variables

FILE_MAP = {
    'motor_off': 'motor_off.xlsx',
    'motor_on': 'motor_on.xlsx',
    'motor_on_nofan': 'motor_on_nofan.xlsx',
    'motor_on_badfan': 'motor_on_badfan.xlsx'
}

SENSOR_COLUMNS = ['ax', 'ay', 'az', 'gx', 'gy', 'gz']
LABEL_COLUMN = 'class_label'
TIME_COLUMN = 'timestamp'

# Windowing params
WINDOW_SIZE = 256
STEP = 128

# Train/test split
TEST_SIZE = 0.2
VAL_SIZE = 0.1  # fraction of train used for validation

BATCH_SIZE = 64
EPOCHS = 60

# %%
# Load datasets

frames = []

for key, fname in FILE_MAP.items():
    df = pd.read_excel(fname)
    df.columns = [c.strip().lower() for c in df.columns]
    frames.append(df)

# Concatenate into a single DataFrame
df_all = pd.concat(frames, axis=0, ignore_index=True)
print(f"Loaded {len(frames)} files. Combined shape: {df_all.shape}")

# Quick type conversions
for col in SENSOR_COLUMNS:
    if col in df_all.columns:
        df_all[col] = pd.to_numeric(df_all[col], errors='coerce')

# If timestamp present, ensure parsed
if TIME_COLUMN in df_all.columns:
    try:
        df_all[TIME_COLUMN] = pd.to_datetime(df_all[TIME_COLUMN])
    except Exception:
        # leave as-is if parsing fails
        pass
# Out:
# Loaded 4 files. Combined shape: (72000, 8)

# %% [markdown]
# ## EDA

# %%
# Value count for columns
print('\n### Value counts of labels:')
print(df_all[LABEL_COLUMN].value_counts())

# Summary statistics for sensor columns
print('\nSummary statistics (sensors):')
print(df_all[SENSOR_COLUMNS].describe().T)
# Out:
# ### Value counts of labels:
# class_label
# 0    18000
# 1    18000
# 2    18000
# 3    18000
# Name: count, dtype: int64
#
# Summary statistics (sensors):
#       count      mean        std        min       25%       50%       75%  \
# ax  72000.0  0.019746   0.122918  -0.371612 -0.014152  0.020740  0.049532
# ay  72000.0 -0.372166   0.485372  -1.469124 -0.934764 -0.137128 -0.038308
# az  72000.0  0.634136   0.613359  -0.972096  0.199348  0.890844  1.023336
# gx  72000.0 -0.704403  10.687206 -43.207500 -3.325000 -0.665000  1.260000
# gy  72000.0 -0.082164   6.769135 -29.242500 -0.437500 -0.087500  0.332500
# gz  72000.0 -0.258987   2.359902  -8.960000 -0.787500 -0.315000  0.245000
#
#           max
# ax   0.428220
# ay   0.535092
# az   2.081564
# gx  41.877500
# gy  32.637500
# gz  10.010000

# %%
# Plot distributions of each sensor channel (random subset if too many points)
PLOT_N = 20000
sample_df = df_all[SENSOR_COLUMNS].sample(min(PLOT_N, len(df_all)))
plt.figure(figsize=(12,6))
for i, col in enumerate(SENSOR_COLUMNS, 1):
    plt.subplot(2, 3, i)
    sns.histplot(sample_df[col].dropna(), bins=100, kde=False)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap for sensor channels
plt.figure(figsize=(6,5))
sns.heatmap(df_all[SENSOR_COLUMNS].corr(), annot=True, fmt='.2f')
plt.title('Sensor-channel correlations')
plt.show()

# %%
# Plot a short time-series snippet per class for visual inspection
plt.figure(figsize=(14,8))
unique_labels = sorted(df_all[LABEL_COLUMN].unique())[:4]
for i, lab in enumerate(unique_labels, 1):
    plt.subplot(len(unique_labels), 1, i)
    sub = df_all[df_all[LABEL_COLUMN] == lab].head(9000)  # first 1000 samples of that class
    if TIME_COLUMN in sub.columns:
        x = sub[TIME_COLUMN]
    else:
        x = np.arange(len(sub))
    plt.plot(x, sub['ax'].values, label='ax', alpha=0.7)
    plt.plot(x, sub['ay'].values, label='ay', alpha=0.6)
    plt.plot(x, sub['az'].values, label='az', alpha=0.6)
    plt.title(f'Class {lab} - first 9000 samples (accelerometer)')
    if i == 1:
        plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
# Windowing raw signals into model-ready arrays
# Creating sliding windows without label-mixing: taking contiguous windows and assigning them
# the most-common label within the window (majority vote). This avoids feature engineering.

# Create numpy arrays from sensors and labels
sensors_arr = df_all[SENSOR_COLUMNS].values.astype('float32')
labels_arr = df_all[LABEL_COLUMN].values

print('Sensors shape (samples, channels):', sensors_arr.shape)

# Sliding window generator
def make_windows(data, labels, window_size=WINDOW_SIZE, step=STEP):
    X = []
    y = []
    n_samples = data.shape[0]
    for start in range(0, n_samples - window_size + 1, step):
        end = start + window_size
        win = data[start:end]
        lab_win = labels[start:end]
        # majority label in the window
        vals, counts = np.unique(lab_win, return_counts=True)
        label = vals[np.argmax(counts)]
        X.append(win)
        y.append(label)
    X = np.array(X)
    y = np.array(y)
    return X, y

X, y = make_windows(sensors_arr, labels_arr, WINDOW_SIZE, STEP)
print('Windows created: X shape =', X.shape, 'y shape =', y.shape)

# Encode labels to 0..n-1
le = LabelEncoder()
y_enc = le.fit_transform(y)
print('Label classes:', le.classes_)
# Out:
# Sensors shape (samples, channels): (72000, 6)
# Windows created: X shape = (561, 256, 6) y shape = (561,)
# Label classes: [0 1 2 3]

# %%
# Train/test split (stratified by window label)
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_enc, test_size=TEST_SIZE, random_state=SEED, stratify=y_enc
)
# Further split train->train+val
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=VAL_SIZE, random_state=SEED, stratify=y_trainval
)

print('Train/Val/Test shapes:', X_train.shape, X_val.shape, X_test.shape)
# Out:
# Train/Val/Test shapes: (403, 256, 6) (45, 256, 6) (113, 256, 6)

# %%
# Scale channels using StandardScaler fit on train windows (fit per channel across all windows/timepoints)
# Reshaping to (n_windows * window_size, n_channels) to fit scaler and then reshape back.

n_channels = X.shape[2]
scaler = StandardScaler()
reshaped = X_train.reshape(-1, n_channels)
scaler.fit(reshaped)

# transform datasets
X_train_scaled = scaler.transform(X_train.reshape(-1, n_channels)).reshape(X_train.shape)
X_val_scaled = scaler.transform(X_val.reshape(-1, n_channels)).reshape(X_val.shape)
X_test_scaled = scaler.transform(X_test.reshape(-1, n_channels)).reshape(X_test.shape)

# Convert labels to categorical
num_classes = len(le.classes_)
y_train_cat = utils.to_categorical(y_train, num_classes)
y_val_cat = utils.to_categorical(y_val, num_classes)
y_test_cat = utils.to_categorical(y_test, num_classes)

# For Keras: ensure dtype float32
X_train_scaled = X_train_scaled.astype('float32')
X_val_scaled = X_val_scaled.astype('float32')
X_test_scaled = X_test_scaled.astype('float32')

# %% [markdown]
# ## Model Architecture

# %%
# 1D-CNN backbone -> DNN (Dense layers)

input_shape = (WINDOW_SIZE, n_channels)
model = models.Sequential([
    layers.Input(shape=input_shape),

    # Conv block 1
    layers.Conv1D(filters=32, kernel_size=7, padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling1D(pool_size=2),

    # Conv block 2
    layers.Conv1D(filters=64, kernel_size=5, padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling1D(pool_size=2),

    # Conv block 3
    layers.Conv1D(filters=128, kernel_size=3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling1D(pool_size=2),

    # Reduce to feature vector
    layers.GlobalAveragePooling1D(),

    # Dense (DNN) head
    layers.Dense(256),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.3),

    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 256, 32)        │         1,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 128, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 128, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 105,252 (411.14 KB)
#  Trainable params: 104,036 (406.39 KB)
#  Non-trainable params: 1,216 (4.75 KB)

# %% [markdown]
# ## Model Training

# %%
# Training

# Callbacks
es = callbacks.EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
rl = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6)


history = model.fit(
X_train_scaled, y_train_cat,
validation_data=(X_val_scaled, y_val_cat),
epochs=EPOCHS,
batch_size=BATCH_SIZE,
callbacks=[es, rl]
)
# Out:
# Epoch 1/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4361 - loss: 1.3888 - val_accuracy: 0.2444 - val_loss: 1.2869 - learning_rate: 0.0010
# Epoch 2/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7015 - loss: 0.7155 - val_accuracy: 0.4444 - val_loss: 1.2265 - learning_rate: 0.0010
# Epoch 3/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7437 - loss: 0.6037 - val_accuracy: 0.6000 - val_loss: 1.1572 - learning_rate: 0.0010
# Epoch 4/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8105 - loss: 0.4515 - val_accuracy: 0.7333 - val_loss: 1.0922 - learning_rate: 0.0010
# Epoch 5/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8267 - loss: 0.3775 - val_accuracy: 0.7333 - val_loss: 1.0233 - learning_rate: 0.0010
# Epoch 6/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8540 - loss: 0.3380 - val_accuracy: 0.7333 - val_loss: 0.9901 - learning_rate: 0.0010
# Epoch 7/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8690 - loss: 0.3141 - val_accuracy: 0.7333 - val_loss: 0.9681 - learning_rate: 0.0010
# Epoch 8/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8908 - loss: 0.2700 - val_accuracy: 0.7333 - val_loss: 0.9204 - learning_rate: 0.0010
# Epoch 9/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9135 - loss: 0.2388 - val_accuracy: 0.7333 - val_loss: 0.9056 - learning_rate: 0.0010
# Epoch 10/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9046 - loss: 0.2355 - val_accuracy: 0.6667 - val_loss: 0.8886 - learning_rate: 0.0010
# Epoch 11/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9070 - loss: 0.2317 - val_accuracy: 0.6889 - val_loss: 0.9032 - learning_rate: 0.0010
# Epoch 12/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9453 - loss: 0.1896 - val_accuracy: 0.6667 - val_loss: 0.9346 - learning_rate: 0.0010
# Epoch 13/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9326 - loss: 0.1827 - val_accuracy: 0.7333 - val_loss: 0.8662 - learning_rate: 0.0010
# Epoch 14/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9250 - loss: 0.1895 - val_accuracy: 0.6667 - val_loss: 0.8643 - learning_rate: 0.0010
# Epoch 15/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9734 - loss: 0.1056 - val_accuracy: 0.7333 - val_loss: 0.8553 - learning_rate: 0.0010
# Epoch 16/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9790 - loss: 0.1123 - val_accuracy: 0.7333 - val_loss: 0.8775 - learning_rate: 0.0010
# Epoch 17/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9890 - loss: 0.0964 - val_accuracy: 0.7333 - val_loss: 0.8403 - learning_rate: 0.0010
# Epoch 18/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0485 - val_accuracy: 0.7111 - val_loss: 0.7807 - learning_rate: 0.0010
# Epoch 19/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9921 - loss: 0.0506 - val_accuracy: 0.7333 - val_loss: 0.7038 - learning_rate: 0.0010
# Epoch 20/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9837 - loss: 0.0848 - val_accuracy: 0.7333 - val_loss: 0.6900 - learning_rate: 0.0010
# Epoch 21/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9706 - loss: 0.0761 - val_accuracy: 0.7333 - val_loss: 0.7850 - learning_rate: 0.0010
# Epoch 22/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9890 - loss: 0.0582 - val_accuracy: 0.6667 - val_loss: 0.7529 - learning_rate: 0.0010
# Epoch 23/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9947 - loss: 0.0466 - val_accuracy: 0.7333 - val_loss: 0.8207 - learning_rate: 0.0010
# Epoch 24/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 0.7333 - val_loss: 0.6229 - learning_rate: 0.0010
# Epoch 25/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.8222 - val_loss: 0.4702 - learning_rate: 0.0010
# Epoch 26/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9946 - loss: 0.0264 - val_accuracy: 0.7556 - val_loss: 0.4075 - learning_rate: 0.0010
# Epoch 27/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.7778 - val_loss: 0.3644 - learning_rate: 0.0010
# Epoch 28/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.7778 - val_loss: 0.3540 - learning_rate: 0.0010
# Epoch 29/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8000 - val_loss: 0.3337 - learning_rate: 0.0010
# Epoch 30/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.8222 - val_loss: 0.2979 - learning_rate: 0.0010
# Epoch 31/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9965 - loss: 0.0128 - val_accuracy: 0.8444 - val_loss: 0.2413 - learning_rate: 0.0010
# Epoch 32/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9333 - val_loss: 0.1757 - learning_rate: 0.0010
# Epoch 33/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.1348 - learning_rate: 0.0010
# Epoch 34/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9975 - loss: 0.0123 - val_accuracy: 0.9333 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 35/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9333 - val_loss: 0.1483 - learning_rate: 0.0010
# Epoch 36/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.1186 - learning_rate: 0.0010
# Epoch 37/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0842 - learning_rate: 0.0010
# Epoch 38/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0601 - learning_rate: 0.0010
# Epoch 39/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 40/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0269 - learning_rate: 0.0010
# Epoch 41/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 42/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0192 - learning_rate: 0.0010
# Epoch 43/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 44/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 45/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 46/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 47/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 48/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 49/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 50/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 51/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 52/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 53/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 54/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 55/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 56/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 57/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 58/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 59/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 60/60
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0013 - learning_rate: 0.0010

# %% [markdown]
# ## Evaluation

# %%
# Plot training curves
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')
plt.show()

# %%
# Using trained model from this session (no disk loading since saving was disabled)
best = model

# Evaluate on test set
test_loss, test_acc = best.evaluate(X_test_scaled, y_test_cat, verbose=0)
print(f'Test loss: {test_loss:.4f}, Test accuracy: {test_acc:.4f}')

# Predictions -> classification report
y_pred_probs = best.predict(X_test_scaled)
y_pred = np.argmax(y_pred_probs, axis=1)

print('\nClassification report:')
print(classification_report(y_test, y_pred, target_names=[str(c) for c in le.classes_]))
# Out:
# Test loss: 0.0351, Test accuracy: 0.9912
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       1.00      0.97      0.98        29
#            2       0.97      1.00      0.98        28
#            3       1.00      1.00      1.00        28
#
#     accuracy                           0.99       113
#    macro avg       0.99      0.99      0.99       113
# weighted avg       0.99      0.99      0.99       113

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

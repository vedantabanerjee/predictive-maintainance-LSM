# %%
# Cell 1: imports & params
import os
import numpy as np
import pandas as pd
from scipy.signal import spectrogram
import joblib
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, callbacks
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold, StratifiedKFold, train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore", category=FutureWarning)

# PARAMETERS (edit these if needed)
DATASET_FOLDER = "dataset"      # folder with your training files (excel/csv)
DATA_COLUMNS = ["ax","ay","az","gx","gy","gz"]  # expected columns in data files
WINDOW_SIZE = 64
STRIDE = WINDOW_SIZE // 2
FS = 100                       # sampling frequency estimate used for spectrogram
SPEC_NPERSEG = 32
SPEC_NOVERLAP = 16
BATCH_SIZE = 64
EPOCHS = 60
LEARNING_RATE = 1e-3
DROPOUT_RATE = 0.35
L2_REG = 1e-4
N_FOLDS = 5
SCALER_PATH = "scaler_1.pkl"
MODEL_SAVE_PATH = "hybrid_model.keras"
ACC_CHANNELS = ["ax","ay","az"]

# %%
# Cell 2: discover dataset files and assign labels (auto-label if explicit map missing)
print("Looking for dataset files in:", DATASET_FOLDER)
found_files = []
for f in os.listdir(DATASET_FOLDER) if os.path.isdir(DATASET_FOLDER) else []:
    if f.lower().endswith((".xlsx",".xls",".csv")):
        found_files.append(f)
found_files = sorted(found_files)
print("Found files:", found_files)

# if you want to explicitly set labels, edit label_map below.
# Default: try to auto-label by filename keywords.
label_map = {
    # "motor_off.xlsx": 0,
    # "motor_on.xlsx": 1,
    # "motor_on_nofan.xlsx": 2,
    # "motor_on_badfan.xlsx": 3
}

auto_labels = {}
if len(found_files) == 0:
    print("No dataset files found in folder. Please place Excel/CSV files in 'dataset' folder and re-run.")
else:
    for fn in found_files:
        low = fn.lower()
        if fn in label_map:
            auto_labels[fn] = label_map[fn]
        elif "off" in low:
            auto_labels[fn] = 0
        elif "nofan" in low or "no_fan" in low or "no-fan" in low:
            auto_labels[fn] = 2
        elif "bad" in low or "badfan" in low or "bad_fan" in low:
            auto_labels[fn] = 3
        elif "on" in low:
            auto_labels[fn] = 1
        else:
            # fallback: treat unknown as class 1 (motor on) but print a warning
            auto_labels[fn] = 1
            print(f"Warning: auto-labeling {fn} as class 1 (please set label_map explicitly if incorrect)")

print("Label mapping (file -> class):")
for k,v in auto_labels.items():
    print(" ", k, "->", v)
# Out:
# Looking for dataset files in: dataset
# Found files: ['motor_off.csv', 'motor_on.csv', 'motor_on_badfan.csv', 'motor_on_nofan.csv']
# Label mapping (file -> class):
#   motor_off.csv -> 0
#   motor_on.csv -> 1
#   motor_on_badfan.csv -> 3
#   motor_on_nofan.csv -> 2

# %%
# Cell 3: fit StandardScaler on concatenated raw sensor rows across all files
all_rows = []
for fn, lbl in auto_labels.items():
    path = os.path.join(DATASET_FOLDER, fn)
    try:
        if fn.lower().endswith(".csv"):
            df = pd.read_csv(path)
        else:
            df = pd.read_excel(path)
    except Exception as e:
        print("Skipping file (read error):", fn, ":", e)
        continue

    missing = [c for c in DATA_COLUMNS if c not in df.columns]
    if missing:
        print(f"Skipping {fn} — missing columns: {missing}")
        continue

    all_rows.append(df[DATA_COLUMNS].values)

if len(all_rows) == 0:
    print("No usable data rows found across files — cannot fit scaler or create windows. Check dataset files and DATA_COLUMNS.")
else:
    stacked = np.vstack(all_rows)
    scaler = StandardScaler()
    scaler.fit(stacked)
    joblib.dump(scaler, SCALER_PATH)
    print(f"Fitted scaler on {stacked.shape[0]} rows and saved to {SCALER_PATH}")
# Out:
# Fitted scaler on 216000 rows and saved to scaler_1.pkl

# %%
# Cell 4: create windows (X), labels (y), groups (group ids)
all_windows = []
all_labels = []
groups = []

if not os.path.exists(SCALER_PATH):
    print("Scaler not found, cannot produce standardized windows. Ensure Cell 3 ran successfully.")
else:
    scaler = joblib.load(SCALER_PATH)
    for fn, lbl in auto_labels.items():
        path = os.path.join(DATASET_FOLDER, fn)
        try:
            if fn.lower().endswith(".csv"):
                df = pd.read_csv(path)
            else:
                df = pd.read_excel(path)
        except Exception as e:
            print("Skipping file (read error):", fn, ":", e)
            continue

        # check columns
        if any(c not in df.columns for c in DATA_COLUMNS):
            print("Skipping file (missing expected cols):", fn)
            continue

        arr = df[DATA_COLUMNS].values
        if arr.shape[0] < WINDOW_SIZE:
            print(f"File too short for windows (len {arr.shape[0]} < {WINDOW_SIZE}): {fn} — skipping")
            continue

        scaled = scaler.transform(arr)
        for start in range(0, scaled.shape[0] - WINDOW_SIZE + 1, STRIDE):
            window = scaled[start:start+WINDOW_SIZE]
            all_windows.append(window)
            all_labels.append(lbl)
            groups.append(fn)   # group by filename

    if len(all_windows) == 0:
        print("No windows were created from dataset. Check your files, DATA_COLUMNS and WINDOW_SIZE.")
    else:
        X = np.array(all_windows, dtype=np.float32)   # (n_windows, WINDOW_SIZE, n_channels)
        y = np.array(all_labels, dtype=np.int32)
        groups = np.array(groups)
        print("Created windows:", X.shape, "Labels:", np.unique(y), "Groups:", len(np.unique(groups)))
# Out:
# Created windows: (6744, 64, 6) Labels: [0 1 2 3] Groups: 4

# %%
# Cell 5: create spectrogram images X_spec for each window (accel channels)
if 'X' not in globals():
    print("X not defined — skipping spectrogram creation. Ensure previous cells created X.")
else:
    # get spectrogram dims from one example
    f, t, Sxx = spectrogram(X[0, :, 0], fs=FS, nperseg=SPEC_NPERSEG, noverlap=SPEC_NOVERLAP)
    freq_bins = len(f)
    time_bins = len(t)
    n_windows = X.shape[0]
    X_spec = np.zeros((n_windows, freq_bins, time_bins, len(ACC_CHANNELS)), dtype=np.float32)

    for i in range(n_windows):
        for ch_idx, ch in enumerate(ACC_CHANNELS):
            col_idx = DATA_COLUMNS.index(ch)
            sig = X[i, :, col_idx]
            f, tt, Sxx = spectrogram(sig, fs=FS, nperseg=SPEC_NPERSEG, noverlap=SPEC_NOVERLAP)
            X_spec[i, :, :, ch_idx] = np.log1p(Sxx)
    print("Created X_spec:", X_spec.shape)
# Out:
# Created X_spec: (6744, 17, 3, 3)

# %%
# Cell 6: build hybrid model
if 'y' not in globals():
    print("y not defined — cannot build model.")
else:
    num_classes = len(np.unique(y))
    tf.keras.backend.clear_session()
    inp1 = layers.Input(shape=(WINDOW_SIZE, len(DATA_COLUMNS)), name='raw_input')
    x = layers.Conv1D(32, 11, padding='same', kernel_regularizer=regularizers.l2(L2_REG))(inp1)
    x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x); x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 9, padding='same', kernel_regularizer=regularizers.l2(L2_REG))(x)
    x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x); x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(128, 5, padding='same', kernel_regularizer=regularizers.l2(L2_REG))(x)
    x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling1D()(x); x = layers.Dropout(DROPOUT_RATE)(x)
    emb1 = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(L2_REG))(x)

    inp2 = layers.Input(shape=(X_spec.shape[1], X_spec.shape[2], X_spec.shape[3]), name='spec_input')
    yb = layers.Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(L2_REG))(inp2)
    yb = layers.BatchNormalization()(yb); yb = layers.Activation('relu')(yb); yb = layers.MaxPooling2D((2,1))(yb)
    yb = layers.Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(L2_REG))(yb)
    yb = layers.BatchNormalization()(yb); yb = layers.Activation('relu')(yb); yb = layers.MaxPooling2D((2,1))(yb)
    yb = layers.Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(L2_REG))(yb)
    yb = layers.BatchNormalization()(yb); yb = layers.Activation('relu')(yb)
    yb = layers.GlobalAveragePooling2D()(yb); yb = layers.Dropout(DROPOUT_RATE)(yb)
    emb2 = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(L2_REG))(yb)

    merged = layers.Concatenate()([emb1, emb2])
    merged = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(L2_REG))(merged)
    merged = layers.Dropout(0.4)(merged)
    out = layers.Dense(num_classes, activation='softmax')(merged)

    hybrid_model_template = models.Model(inputs=[inp1, inp2], outputs=out, name='hybrid_template')
    hybrid_model_template.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                                  loss='categorical_crossentropy', metrics=['accuracy'])
    hybrid_model_template.summary()
# Out:
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Cell 7 (REPLACEMENT): Train the hybrid model with safe fold strategy (fixed compute_class_weight usage)
from sklearn.utils.class_weight import compute_class_weight

if 'X' not in globals() or 'X_spec' not in globals() or 'y' not in globals():
    print("Missing X, X_spec or y — cannot run training. Ensure previous cells executed successfully.")
else:
    # decide fold strategy
    unique_groups = np.unique(groups)
    if len(unique_groups) >= N_FOLDS:
        splitter = GroupKFold(n_splits=N_FOLDS)
        split_type = "GroupKFold"
    else:
        unique_labels, counts = np.unique(y, return_counts=True)
        if np.min(counts) >= N_FOLDS:
            splitter = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
            split_type = "StratifiedKFold"
        else:
            # fallback to a single train/Test split
            X_train, X_val, Xspec_train, Xspec_val, y_train, y_val = train_test_split(
                X, X_spec, y, test_size=0.2, stratify=y if len(np.unique(y)) > 1 else None, random_state=42)
            splitter = None
            split_type = "TrainTestSplit"
    print("Using split strategy:", split_type)

    # Training loop
    if split_type in ("GroupKFold", "StratifiedKFold"):
        fold = 0
        histories = []
        # use appropriate split call
        if split_type == "GroupKFold":
            split_gen = splitter.split(X, y, groups)
        else:
            split_gen = splitter.split(X, y)

        for train_idx, val_idx in split_gen:
            print(f"\n--- Fold {fold} ---")
            X_tr, X_val = X[train_idx], X[val_idx]
            Xspec_tr, Xspec_val = X_spec[train_idx], X_spec[val_idx]
            y_tr, y_val = y[train_idx], y[val_idx]

            # compute class weights correctly (keyword args required in newer sklearn)
            classes_in_tr = np.unique(y_tr)
            weights = compute_class_weight(class_weight='balanced', classes=classes_in_tr, y=y_tr)
            class_weight = {int(cls): float(w) for cls, w in zip(classes_in_tr, weights)}
            print("Class weights:", class_weight)

            # to categorical
            y_tr_cat = tf.keras.utils.to_categorical(y_tr, num_classes=num_classes)
            y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=num_classes)

            # new model per fold (clone from template)
            tf.keras.backend.clear_session()
            model = tf.keras.models.clone_model(hybrid_model_template)
            # compile fresh
            model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                          loss='categorical_crossentropy', metrics=['accuracy'])
            model.summary()

            # Callbacks
            cb_early = callbacks.EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True, verbose=1)
            cb_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, verbose=1, min_lr=1e-6)
            ckpt = f"hybrid_best_fold{fold}.keras"
            cb_ckpt = callbacks.ModelCheckpoint(ckpt, monitor='val_loss', save_best_only=True, verbose=0)

            history = model.fit(
                [X_tr, Xspec_tr], y_tr_cat,
                validation_data=([X_val, Xspec_val], y_val_cat),
                epochs=EPOCHS,
                batch_size=BATCH_SIZE,
                callbacks=[cb_early, cb_lr, cb_ckpt],
                class_weight=class_weight,
                verbose=2
            )
            histories.append(history.history)

            # Save fold model
            model.save(f"hybrid_model_fold{fold}.keras")
            print(f"Saved fold model hybrid_model_fold{fold}.keras and checkpoint {ckpt}")

            fold += 1
            if fold >= N_FOLDS:
                break

        # choose best fold (fold0) as canonical model if available
        if os.path.exists("hybrid_best_fold0.keras"):
            best = tf.keras.models.load_model("hybrid_best_fold0.keras")
            best.save(MODEL_SAVE_PATH)
            print("Saved canonical model:", MODEL_SAVE_PATH)
        else:
            print("No fold checkpoint found; training completed but no checkpoint present.")
    else:
        # Single split fallback training
        print("Training with single train/test split.")
        y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=num_classes)
        y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=num_classes)

        classes_in_tr = np.unique(y_train)
        weights = compute_class_weight(class_weight='balanced', classes=classes_in_tr, y=y_train)
        class_weight = {int(cls): float(w) for cls, w in zip(classes_in_tr, weights)}
        print("Class weights (single split):", class_weight)

        tf.keras.backend.clear_session()
        model = tf.keras.models.clone_model(hybrid_model_template)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                      loss='categorical_crossentropy', metrics=['accuracy'])

        cb_early = callbacks.EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True, verbose=1)
        cb_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, min_lr=1e-6, verbose=1)
        ckpt = "hybrid_best_split.keras"
        cb_ckpt = callbacks.ModelCheckpoint(ckpt, monitor='val_loss', save_best_only=True, verbose=0)

        history = model.fit(
            [X_train, Xspec_train], y_train_cat,
            validation_data=([X_val, Xspec_val], y_val_cat),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            callbacks=[cb_early, cb_lr, cb_ckpt],
            class_weight=class_weight,
            verbose=2
        )

        if os.path.exists(ckpt):
            best = tf.keras.models.load_model(ckpt)
            best.save(MODEL_SAVE_PATH)
            print("Saved model:", MODEL_SAVE_PATH)
        else:
            model.save(MODEL_SAVE_PATH)
            print("Saved model (no ckpt):", MODEL_SAVE_PATH)
# Out:
# Using split strategy: StratifiedKFold
#
# --- Fold 0 ---
# Class weights: {0: 1.0005563798219586, 1: 0.9998146775389177, 2: 0.9998146775389177, 3: 0.9998146775389177}
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/60
# 85/85 - 3s - 35ms/step - accuracy: 0.6847 - loss: 0.7806 - val_accuracy: 0.6012 - val_loss: 0.8510 - learning_rate: 0.0010
# Epoch 2/60
# 85/85 - 1s - 13ms/step - accuracy: 0.8614 - loss: 0.3693 - val_accuracy: 0.7064 - val_loss: 0.6803 - learning_rate: 0.0010
# Epoch 3/60
# 85/85 - 1s - 13ms/step - accuracy: 0.8843 - loss: 0.3204 - val_accuracy: 0.5604 - val_loss: 0.9473 - learning_rate: 0.0010
# Epoch 4/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9164 - loss: 0.2459 - val_accuracy: 0.5189 - val_loss: 1.4410 - learning_rate: 0.0010
# Epoch 5/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9349 - loss: 0.2052 - val_accuracy: 0.7294 - val_loss: 1.0264 - learning_rate: 0.0010
# Epoch 6/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9464 - loss: 0.1944 - val_accuracy: 0.4277 - val_loss: 7.9381 - learning_rate: 0.0010
# Epoch 7/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9483 - loss: 0.1854 - val_accuracy: 0.5641 - val_loss: 3.6553 - learning_rate: 0.0010
# Epoch 8/60
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 - 1s - 13ms/step - accuracy: 0.9618 - loss: 0.1516 - val_accuracy: 0.7087 - val_loss: 1.7379 - learning_rate: 0.0010
# Epoch 9/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9755 - loss: 0.1201 - val_accuracy: 0.8184 - val_loss: 0.8723 - learning_rate: 5.0000e-04
# Epoch 10/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9722 - loss: 0.1234 - val_accuracy: 0.6761 - val_loss: 2.5162 - learning_rate: 5.0000e-04
# Epoch 11/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9759 - loss: 0.1182 - val_accuracy: 0.7620 - val_loss: 1.1634 - learning_rate: 5.0000e-04
# Epoch 12/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9752 - loss: 0.1236 - val_accuracy: 0.6249 - val_loss: 5.9573 - learning_rate: 5.0000e-04
# Epoch 13/60
# 85/85 - 1s - 12ms/step - accuracy: 0.9804 - loss: 0.1089 - val_accuracy: 0.6879 - val_loss: 1.8494 - learning_rate: 5.0000e-04
# Epoch 14/60
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 - 1s - 13ms/step - accuracy: 0.9861 - loss: 0.0939 - val_accuracy: 0.6990 - val_loss: 2.6501 - learning_rate: 5.0000e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Saved fold model hybrid_model_fold0.keras and checkpoint hybrid_best_fold0.keras
#
# --- Fold 1 ---
# Class weights: {0: 0.9998146775389177, 1: 1.0005563798219586, 2: 0.9998146775389177, 3: 0.9998146775389177}
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/60
# 85/85 - 3s - 36ms/step - accuracy: 0.6867 - loss: 0.7907 - val_accuracy: 0.4025 - val_loss: 1.2758 - learning_rate: 0.0010
# Epoch 2/60
# 85/85 - 1s - 15ms/step - accuracy: 0.8271 - loss: 0.4328 - val_accuracy: 0.5152 - val_loss: 1.1684 - learning_rate: 0.0010
# Epoch 3/60
# 85/85 - 1s - 13ms/step - accuracy: 0.8845 - loss: 0.3095 - val_accuracy: 0.5204 - val_loss: 1.8552 - learning_rate: 0.0010
# Epoch 4/60
# 85/85 - 1s - 12ms/step - accuracy: 0.8999 - loss: 0.2773 - val_accuracy: 0.5812 - val_loss: 1.7274 - learning_rate: 0.0010
# Epoch 5/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9079 - loss: 0.2596 - val_accuracy: 0.5901 - val_loss: 1.9149 - learning_rate: 0.0010
# Epoch 6/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9270 - loss: 0.2254 - val_accuracy: 0.6049 - val_loss: 1.9857 - learning_rate: 0.0010
# Epoch 7/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9333 - loss: 0.2044 - val_accuracy: 0.7042 - val_loss: 1.8676 - learning_rate: 0.0010
# Epoch 8/60
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 - 1s - 13ms/step - accuracy: 0.9431 - loss: 0.1895 - val_accuracy: 0.6286 - val_loss: 2.2207 - learning_rate: 0.0010
# Epoch 9/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9596 - loss: 0.1569 - val_accuracy: 0.6627 - val_loss: 1.7518 - learning_rate: 5.0000e-04
# Epoch 10/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9629 - loss: 0.1469 - val_accuracy: 0.8547 - val_loss: 0.8694 - learning_rate: 5.0000e-04
# Epoch 11/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9648 - loss: 0.1440 - val_accuracy: 0.8562 - val_loss: 0.6246 - learning_rate: 5.0000e-04
# Epoch 12/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9698 - loss: 0.1351 - val_accuracy: 0.7532 - val_loss: 1.4750 - learning_rate: 5.0000e-04
# Epoch 13/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9729 - loss: 0.1234 - val_accuracy: 0.3291 - val_loss: 27.3584 - learning_rate: 5.0000e-04
# Epoch 14/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9776 - loss: 0.1126 - val_accuracy: 0.5026 - val_loss: 9.2251 - learning_rate: 5.0000e-04
# Epoch 15/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9750 - loss: 0.1175 - val_accuracy: 0.7591 - val_loss: 2.0702 - learning_rate: 5.0000e-04
# Epoch 16/60
# 85/85 - 1s - 12ms/step - accuracy: 0.9787 - loss: 0.1082 - val_accuracy: 0.5723 - val_loss: 1.7644 - learning_rate: 5.0000e-04
# Epoch 17/60
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 - 1s - 13ms/step - accuracy: 0.9809 - loss: 0.1096 - val_accuracy: 0.6812 - val_loss: 4.0748 - learning_rate: 5.0000e-04
# Epoch 18/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9892 - loss: 0.0884 - val_accuracy: 0.6916 - val_loss: 2.9067 - learning_rate: 2.5000e-04
# Epoch 19/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9896 - loss: 0.0856 - val_accuracy: 0.7072 - val_loss: 2.3612 - learning_rate: 2.5000e-04
# Epoch 20/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9917 - loss: 0.0786 - val_accuracy: 0.6701 - val_loss: 1.0433 - learning_rate: 2.5000e-04
# Epoch 21/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9918 - loss: 0.0781 - val_accuracy: 0.9459 - val_loss: 0.2604 - learning_rate: 2.5000e-04
# Epoch 22/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9907 - loss: 0.0790 - val_accuracy: 0.6909 - val_loss: 3.7295 - learning_rate: 2.5000e-04
# Epoch 23/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9909 - loss: 0.0750 - val_accuracy: 0.7991 - val_loss: 1.9308 - learning_rate: 2.5000e-04
# Epoch 24/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9918 - loss: 0.0765 - val_accuracy: 0.8206 - val_loss: 0.9980 - learning_rate: 2.5000e-04
# Epoch 25/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9918 - loss: 0.0766 - val_accuracy: 0.7042 - val_loss: 0.9616 - learning_rate: 2.5000e-04
# Epoch 26/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9935 - loss: 0.0706 - val_accuracy: 0.9629 - val_loss: 0.1200 - learning_rate: 2.5000e-04
# Epoch 27/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9889 - loss: 0.0799 - val_accuracy: 0.7079 - val_loss: 3.8407 - learning_rate: 2.5000e-04
# Epoch 28/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9939 - loss: 0.0682 - val_accuracy: 0.9615 - val_loss: 0.1801 - learning_rate: 2.5000e-04
# Epoch 29/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9924 - loss: 0.0723 - val_accuracy: 0.7020 - val_loss: 2.1990 - learning_rate: 2.5000e-04
# Epoch 30/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9889 - loss: 0.0796 - val_accuracy: 0.9867 - val_loss: 0.0891 - learning_rate: 2.5000e-04
# Epoch 31/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9963 - loss: 0.0622 - val_accuracy: 0.9778 - val_loss: 0.1231 - learning_rate: 2.5000e-04
# Epoch 32/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9950 - loss: 0.0641 - val_accuracy: 0.9481 - val_loss: 0.2349 - learning_rate: 2.5000e-04
# Epoch 33/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9937 - loss: 0.0642 - val_accuracy: 0.6227 - val_loss: 2.1909 - learning_rate: 2.5000e-04
# Epoch 34/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9933 - loss: 0.0661 - val_accuracy: 0.8710 - val_loss: 0.7962 - learning_rate: 2.5000e-04
# Epoch 35/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9943 - loss: 0.0684 - val_accuracy: 0.9325 - val_loss: 0.3601 - learning_rate: 2.5000e-04
# Epoch 36/60
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 85/85 - 1s - 14ms/step - accuracy: 0.9918 - loss: 0.0781 - val_accuracy: 0.8807 - val_loss: 0.5356 - learning_rate: 2.5000e-04
# Epoch 37/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9944 - loss: 0.0640 - val_accuracy: 0.9600 - val_loss: 0.1747 - learning_rate: 1.2500e-04
# Epoch 38/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9959 - loss: 0.0595 - val_accuracy: 0.9644 - val_loss: 0.1628 - learning_rate: 1.2500e-04
# Epoch 39/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9972 - loss: 0.0578 - val_accuracy: 0.9741 - val_loss: 0.1107 - learning_rate: 1.2500e-04
# Epoch 40/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9957 - loss: 0.0601 - val_accuracy: 0.9644 - val_loss: 0.1576 - learning_rate: 1.2500e-04
# Epoch 41/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9954 - loss: 0.0593 - val_accuracy: 0.9792 - val_loss: 0.1007 - learning_rate: 1.2500e-04
# Epoch 42/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9944 - loss: 0.0644 - val_accuracy: 0.9904 - val_loss: 0.0826 - learning_rate: 1.2500e-04
# Epoch 43/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9952 - loss: 0.0616 - val_accuracy: 0.7324 - val_loss: 0.9814 - learning_rate: 1.2500e-04
# Epoch 44/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9974 - loss: 0.0569 - val_accuracy: 0.9481 - val_loss: 0.2824 - learning_rate: 1.2500e-04
# Epoch 45/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9967 - loss: 0.0577 - val_accuracy: 0.9904 - val_loss: 0.0720 - learning_rate: 1.2500e-04
# Epoch 46/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9968 - loss: 0.0559 - val_accuracy: 0.9830 - val_loss: 0.1078 - learning_rate: 1.2500e-04
# Epoch 47/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9970 - loss: 0.0549 - val_accuracy: 0.9815 - val_loss: 0.1139 - learning_rate: 1.2500e-04
# Epoch 48/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9965 - loss: 0.0553 - val_accuracy: 0.8947 - val_loss: 0.5862 - learning_rate: 1.2500e-04
# Epoch 49/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9980 - loss: 0.0532 - val_accuracy: 0.9785 - val_loss: 0.1240 - learning_rate: 1.2500e-04
# Epoch 50/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9939 - loss: 0.0621 - val_accuracy: 0.9511 - val_loss: 0.2524 - learning_rate: 1.2500e-04
# Epoch 51/60
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 85/85 - 1s - 14ms/step - accuracy: 0.9954 - loss: 0.0599 - val_accuracy: 0.9518 - val_loss: 0.2265 - learning_rate: 1.2500e-04
# Epoch 52/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9985 - loss: 0.0509 - val_accuracy: 0.9911 - val_loss: 0.0741 - learning_rate: 6.2500e-05
# Epoch 53/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9978 - loss: 0.0521 - val_accuracy: 0.9956 - val_loss: 0.0621 - learning_rate: 6.2500e-05
# Epoch 54/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9968 - loss: 0.0536 - val_accuracy: 0.9941 - val_loss: 0.0617 - learning_rate: 6.2500e-05
# Epoch 55/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9980 - loss: 0.0504 - val_accuracy: 0.9963 - val_loss: 0.0592 - learning_rate: 6.2500e-05
# Epoch 56/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9974 - loss: 0.0507 - val_accuracy: 0.9281 - val_loss: 0.4483 - learning_rate: 6.2500e-05
# Epoch 57/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9991 - loss: 0.0478 - val_accuracy: 0.9956 - val_loss: 0.0609 - learning_rate: 6.2500e-05
# Epoch 58/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9981 - loss: 0.0499 - val_accuracy: 0.7450 - val_loss: 0.8191 - learning_rate: 6.2500e-05
# Epoch 59/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9983 - loss: 0.0497 - val_accuracy: 0.9970 - val_loss: 0.0561 - learning_rate: 6.2500e-05
# Epoch 60/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9978 - loss: 0.0502 - val_accuracy: 0.9933 - val_loss: 0.0632 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 59.
# Saved fold model hybrid_model_fold1.keras and checkpoint hybrid_best_fold1.keras
#
# --- Fold 2 ---
# Class weights: {0: 0.9998146775389177, 1: 0.9998146775389177, 2: 0.9998146775389177, 3: 1.0005563798219586}
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/60
# 85/85 - 3s - 35ms/step - accuracy: 0.6786 - loss: 0.7846 - val_accuracy: 0.5656 - val_loss: 0.9808 - learning_rate: 0.0010
# Epoch 2/60
# 85/85 - 1s - 14ms/step - accuracy: 0.8565 - loss: 0.3733 - val_accuracy: 0.6872 - val_loss: 0.6708 - learning_rate: 0.0010
# Epoch 3/60
# 85/85 - 1s - 13ms/step - accuracy: 0.8879 - loss: 0.2973 - val_accuracy: 0.7798 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 4/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9095 - loss: 0.2628 - val_accuracy: 0.8302 - val_loss: 0.4282 - learning_rate: 0.0010
# Epoch 5/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9264 - loss: 0.2258 - val_accuracy: 0.8747 - val_loss: 0.3555 - learning_rate: 0.0010
# Epoch 6/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9409 - loss: 0.1958 - val_accuracy: 0.8895 - val_loss: 0.3550 - learning_rate: 0.0010
# Epoch 7/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9294 - loss: 0.2266 - val_accuracy: 0.7146 - val_loss: 0.7077 - learning_rate: 0.0010
# Epoch 8/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9496 - loss: 0.1866 - val_accuracy: 0.3944 - val_loss: 7.0941 - learning_rate: 0.0010
# Epoch 9/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9674 - loss: 0.1377 - val_accuracy: 0.3714 - val_loss: 14.4129 - learning_rate: 0.0010
# Epoch 10/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9587 - loss: 0.1576 - val_accuracy: 0.3491 - val_loss: 9.6310 - learning_rate: 0.0010
# Epoch 11/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9789 - loss: 0.1146 - val_accuracy: 0.6323 - val_loss: 3.6962 - learning_rate: 0.0010
# Epoch 12/60
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 - 1s - 13ms/step - accuracy: 0.9842 - loss: 0.1051 - val_accuracy: 0.6042 - val_loss: 2.2162 - learning_rate: 0.0010
# Epoch 13/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9887 - loss: 0.0874 - val_accuracy: 0.6019 - val_loss: 2.7808 - learning_rate: 5.0000e-04
# Epoch 14/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9850 - loss: 0.0973 - val_accuracy: 0.9073 - val_loss: 1.0352 - learning_rate: 5.0000e-04
# Epoch 15/60
# 85/85 - 1s - 13ms/step - accuracy: 0.9855 - loss: 0.0950 - val_accuracy: 0.6627 - val_loss: 2.2946 - learning_rate: 5.0000e-04
# Epoch 16/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9922 - loss: 0.0772 - val_accuracy: 0.6516 - val_loss: 2.3885 - learning_rate: 5.0000e-04
# Epoch 17/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9937 - loss: 0.0714 - val_accuracy: 0.8599 - val_loss: 1.1763 - learning_rate: 5.0000e-04
# Epoch 18/60
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 - 1s - 14ms/step - accuracy: 0.9902 - loss: 0.0761 - val_accuracy: 0.9407 - val_loss: 0.5062 - learning_rate: 5.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Saved fold model hybrid_model_fold2.keras and checkpoint hybrid_best_fold2.keras
#
# --- Fold 3 ---
# Class weights: {0: 0.9998146775389177, 1: 0.9998146775389177, 2: 1.0005563798219586, 3: 0.9998146775389177}
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/60
# 85/85 - 3s - 37ms/step - accuracy: 0.6895 - loss: 0.7613 - val_accuracy: 0.7153 - val_loss: 0.7615 - learning_rate: 0.0010
# Epoch 2/60
# 85/85 - 1s - 13ms/step - accuracy: 0.8525 - loss: 0.3814 - val_accuracy: 0.5486 - val_loss: 1.0046 - learning_rate: 0.0010
# Epoch 3/60
# 85/85 - 1s - 14ms/step - accuracy: 0.8982 - loss: 0.2906 - val_accuracy: 0.8117 - val_loss: 0.6079 - learning_rate: 0.0010
# Epoch 4/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9194 - loss: 0.2397 - val_accuracy: 0.6457 - val_loss: 0.7220 - learning_rate: 0.0010
# Epoch 5/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9285 - loss: 0.2322 - val_accuracy: 0.6560 - val_loss: 1.1120 - learning_rate: 0.0010
# Epoch 6/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9372 - loss: 0.2130 - val_accuracy: 0.7035 - val_loss: 1.4441 - learning_rate: 0.0010
# Epoch 7/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9527 - loss: 0.1814 - val_accuracy: 0.6153 - val_loss: 1.1923 - learning_rate: 0.0010
# Epoch 8/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9587 - loss: 0.1629 - val_accuracy: 0.5226 - val_loss: 2.7014 - learning_rate: 0.0010
# Epoch 9/60
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 - 1s - 13ms/step - accuracy: 0.9707 - loss: 0.1332 - val_accuracy: 0.8540 - val_loss: 0.6349 - learning_rate: 0.0010
# Epoch 10/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9809 - loss: 0.1093 - val_accuracy: 0.8688 - val_loss: 0.7797 - learning_rate: 5.0000e-04
# Epoch 11/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9824 - loss: 0.1076 - val_accuracy: 0.8992 - val_loss: 0.3063 - learning_rate: 5.0000e-04
# Epoch 12/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9854 - loss: 0.1011 - val_accuracy: 0.6976 - val_loss: 1.2178 - learning_rate: 5.0000e-04
# Epoch 13/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9865 - loss: 0.0925 - val_accuracy: 0.6227 - val_loss: 3.0058 - learning_rate: 5.0000e-04
# Epoch 14/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9870 - loss: 0.0917 - val_accuracy: 0.9600 - val_loss: 0.2379 - learning_rate: 5.0000e-04
# Epoch 15/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9872 - loss: 0.0906 - val_accuracy: 0.8962 - val_loss: 0.3766 - learning_rate: 5.0000e-04
# Epoch 16/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9909 - loss: 0.0787 - val_accuracy: 0.9948 - val_loss: 0.0741 - learning_rate: 5.0000e-04
# Epoch 17/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9935 - loss: 0.0716 - val_accuracy: 0.7228 - val_loss: 1.2219 - learning_rate: 5.0000e-04
# Epoch 18/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9894 - loss: 0.0800 - val_accuracy: 0.8844 - val_loss: 0.5124 - learning_rate: 5.0000e-04
# Epoch 19/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9928 - loss: 0.0730 - val_accuracy: 0.9689 - val_loss: 0.1237 - learning_rate: 5.0000e-04
# Epoch 20/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9867 - loss: 0.0881 - val_accuracy: 0.6820 - val_loss: 1.2495 - learning_rate: 5.0000e-04
# Epoch 21/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9904 - loss: 0.0812 - val_accuracy: 0.9148 - val_loss: 0.3804 - learning_rate: 5.0000e-04
# Epoch 22/60
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 - 1s - 14ms/step - accuracy: 0.9944 - loss: 0.0686 - val_accuracy: 0.8406 - val_loss: 0.4418 - learning_rate: 5.0000e-04
# Epoch 23/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9935 - loss: 0.0662 - val_accuracy: 0.8873 - val_loss: 0.5252 - learning_rate: 2.5000e-04
# Epoch 24/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9959 - loss: 0.0627 - val_accuracy: 0.9073 - val_loss: 0.3844 - learning_rate: 2.5000e-04
# Epoch 25/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9974 - loss: 0.0570 - val_accuracy: 0.9429 - val_loss: 0.2554 - learning_rate: 2.5000e-04
# Epoch 26/60
# 85/85 - 1s - 16ms/step - accuracy: 0.9959 - loss: 0.0592 - val_accuracy: 0.9763 - val_loss: 0.1042 - learning_rate: 2.5000e-04
# Epoch 27/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9967 - loss: 0.0569 - val_accuracy: 0.9592 - val_loss: 0.1563 - learning_rate: 2.5000e-04
# Epoch 28/60
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 85/85 - 1s - 14ms/step - accuracy: 0.9954 - loss: 0.0600 - val_accuracy: 0.9014 - val_loss: 0.3901 - learning_rate: 2.5000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Saved fold model hybrid_model_fold3.keras and checkpoint hybrid_best_fold3.keras
#
# --- Fold 4 ---
# Class weights: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}
# Model: "hybrid_template"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ raw_input           │ (None, 64, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 17, 3, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │      2,144 │ raw_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 3, 32) │        896 │ spec_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 3, 32) │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 32)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 17, 3, 32) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 32, 32)    │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 3, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 64)    │     18,496 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 3, 64)  │     18,496 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 3, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 3, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 16, 64)    │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 3, 64)  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 128)   │     41,088 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 128) │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │        516 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 190,308 (743.39 KB)
#  Trainable params: 189,412 (739.89 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/60
# 85/85 - 3s - 36ms/step - accuracy: 0.6914 - loss: 0.7454 - val_accuracy: 0.5274 - val_loss: 1.0339 - learning_rate: 0.0010
# Epoch 2/60
# 85/85 - 1s - 14ms/step - accuracy: 0.8556 - loss: 0.3814 - val_accuracy: 0.6914 - val_loss: 0.6601 - learning_rate: 0.0010
# Epoch 3/60
# 85/85 - 1s - 14ms/step - accuracy: 0.8881 - loss: 0.2930 - val_accuracy: 0.6936 - val_loss: 0.8587 - learning_rate: 0.0010
# Epoch 4/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9012 - loss: 0.2720 - val_accuracy: 0.5727 - val_loss: 1.4956 - learning_rate: 0.0010
# Epoch 5/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9036 - loss: 0.2710 - val_accuracy: 0.5920 - val_loss: 1.7362 - learning_rate: 0.0010
# Epoch 6/60
# 85/85 - 1s - 15ms/step - accuracy: 0.9372 - loss: 0.2039 - val_accuracy: 0.8353 - val_loss: 0.4023 - learning_rate: 0.0010
# Epoch 7/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9466 - loss: 0.1848 - val_accuracy: 0.7953 - val_loss: 0.7141 - learning_rate: 0.0010
# Epoch 8/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9461 - loss: 0.1866 - val_accuracy: 0.6907 - val_loss: 1.8022 - learning_rate: 0.0010
# Epoch 9/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9596 - loss: 0.1547 - val_accuracy: 0.5430 - val_loss: 5.9915 - learning_rate: 0.0010
# Epoch 10/60
# 85/85 - 1s - 16ms/step - accuracy: 0.9540 - loss: 0.1735 - val_accuracy: 0.8108 - val_loss: 0.8064 - learning_rate: 0.0010
# Epoch 11/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9596 - loss: 0.1535 - val_accuracy: 0.6276 - val_loss: 2.3662 - learning_rate: 0.0010
# Epoch 12/60
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 - 1s - 13ms/step - accuracy: 0.9731 - loss: 0.1230 - val_accuracy: 0.2589 - val_loss: 27.8458 - learning_rate: 0.0010
# Epoch 13/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9761 - loss: 0.1193 - val_accuracy: 0.4911 - val_loss: 6.7823 - learning_rate: 5.0000e-04
# Epoch 14/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9824 - loss: 0.1040 - val_accuracy: 0.4918 - val_loss: 8.0123 - learning_rate: 5.0000e-04
# Epoch 15/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9854 - loss: 0.0931 - val_accuracy: 0.6654 - val_loss: 3.3839 - learning_rate: 5.0000e-04
# Epoch 16/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9880 - loss: 0.0854 - val_accuracy: 0.6706 - val_loss: 1.1348 - learning_rate: 5.0000e-04
# Epoch 17/60
# 85/85 - 1s - 14ms/step - accuracy: 0.9850 - loss: 0.0868 - val_accuracy: 0.6424 - val_loss: 1.9532 - learning_rate: 5.0000e-04
# Epoch 18/60
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 - 1s - 14ms/step - accuracy: 0.9818 - loss: 0.1040 - val_accuracy: 0.9110 - val_loss: 0.4083 - learning_rate: 5.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Saved fold model hybrid_model_fold4.keras and checkpoint hybrid_best_fold4.keras
# Saved canonical model: hybrid_model.keras

# %%
# Cell 8: quick evaluation on validation or full windows (if model exists)
if not os.path.exists(MODEL_SAVE_PATH):
    print("Model not found at", MODEL_SAVE_PATH, " — skip evaluation.")
else:
    model = tf.keras.models.load_model(MODEL_SAVE_PATH)
    # Evaluate on the full dataset windows (not ideal for real eval, but gives quick numbers)
    preds = model.predict([X, X_spec], verbose=0)
    pred_classes = np.argmax(preds, axis=1)
    acc = accuracy_score(y, pred_classes)
    f1 = f1_score(y, pred_classes, average='weighted')
    prec = precision_score(y, pred_classes, average='weighted', zero_division=0)
    rec = recall_score(y, pred_classes, average='weighted', zero_division=0)
    print(f"Quick eval on all windows -> acc: {acc:.3f}, f1: {f1:.3f}, prec: {prec:.3f}, rec: {rec:.3f}")
# Out:
# Quick eval on all windows -> acc: 0.705, f1: 0.703, prec: 0.730, rec: 0.705

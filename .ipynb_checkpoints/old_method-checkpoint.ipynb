# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.fft import fft
from scipy.stats import mode, skew, kurtosis

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from tensorflow.keras.models import clone_model

from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc, precision_recall_curve

# %%
# Loading Data
files = {
    "motor_OFF": "motor_OFF.xlsx",
    "motor_ON": "motor_ON.xlsx",
    "motor_ON_NO_FAN": "motor_ON_NO_fan.xlsx",
    "motor_ON_BAD_FAN": "motor_ON_BAD_FAN.xlsx"
}

# Read each into a DataFrame and tag with its source
dataframes = {}
for label, path in files.items():
    df = pd.read_excel(path)
    df['source'] = label
    dataframes[label] = df

# Combine into one DataFrame (we’ll still use 'dataframes' for segmentation)
all_df = pd.concat(dataframes.values(), ignore_index=True)
print("Combined shape:", all_df.shape)
# Out:
# Combined shape: (4000, 6)

# %% [markdown]
# ## EDA

# %%
# 1. Class Distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=all_df, x="class_label")
plt.title("Class Distribution")
plt.xlabel("Class Label")
plt.ylabel("Count")
plt.show()

# %%
# 2. Signal Stats Summary
print("Signal Statistics Summary:")
print(all_df[['x_axis', 'y_axis', 'z_axis']].describe())
# Out:
# Signal Statistics Summary:
#             x_axis       y_axis       z_axis
# count  4000.000000  4000.000000  4000.000000
# mean      0.594766     0.287447    11.146878
# std       1.568819     5.953347     1.557541
# min      -3.533842   -13.048400     7.223307
# 25%      -0.526724    -2.680309    10.299860
# 50%       0.462081     0.284910    11.137830
# 75%       1.719635     3.518878    12.148180
# max       4.498705    14.022840    14.947000

# %%
# 3. Time-domain Plots (Sample 200 points for readability)
for name, df in dataframes.items():
    plt.figure(figsize=(10, 3))
    plt.plot(df["x_axis"][:200], label="x", alpha=0.7)
    plt.plot(df["y_axis"][:200], label="y", alpha=0.7)
    plt.plot(df["z_axis"][:200], label="z", alpha=0.7)
    plt.title(f"Time-domain Signal - {name}")
    plt.xlabel("Time index")
    plt.ylabel("Acceleration")
    plt.legend()
    plt.show()

# %%
# 4. Correlation Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(all_df[["x_axis", "y_axis", "z_axis"]].corr(), annot=True, cmap="coolwarm")
plt.title("Axis Correlation Matrix")
plt.show()

# %%
# 5. FFT for Frequency Analysis
def plot_fft(signal, title):
    signal = pd.to_numeric(signal, errors="coerce").dropna().to_numpy()
    N = len(signal)
    fft_vals = np.abs(fft(signal))[:N // 2]
    freqs = np.fft.fftfreq(N, d=1/100)[:N // 2]  # Assuming 100 Hz sampling
    plt.figure(figsize=(8, 3))
    plt.plot(freqs, fft_vals)
    plt.title(f"FFT - {title}")
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Amplitude")
    plt.grid(True)
    plt.show()

# For MOTOR_ON
plot_fft(dataframes["motor_ON"]["x_axis"], "motor_ON X-axis")
plot_fft(dataframes["motor_ON"]["y_axis"], "motor_ON Y-axis")
plot_fft(dataframes["motor_ON"]["z_axis"], "motor_ON Z-axis")

# For MOTOR_OFF
plot_fft(dataframes["motor_ON"]["x_axis"], "motor_OFF X-axis")
plot_fft(dataframes["motor_ON"]["y_axis"], "motor_OFF Y-axis")
plot_fft(dataframes["motor_ON"]["z_axis"], "motor_OFF Z-axis")

# For MOTOR_ON_NO_FAN
plot_fft(dataframes["motor_ON"]["x_axis"], "motor_ON_NO_FAN X-axis")
plot_fft(dataframes["motor_ON"]["y_axis"], "motor_ON_NO_FAN Y-axis")
plot_fft(dataframes["motor_ON"]["z_axis"], "motor_ON_NO_FAN Z-axis")

# For MOTOR_ON_BAD_FAN
plot_fft(dataframes["motor_ON"]["x_axis"], "motor_ON_BAD_FAN X-axis")
plot_fft(dataframes["motor_ON"]["y_axis"], "motor_ON_BAD_FAN Y-axis")
plot_fft(dataframes["motor_ON"]["z_axis"], "motor_ON_BAD_FAN Z-axis")

# %%
# 6. Rolling Variance (Signal Stability)
roll_window = 50
for name, df in dataframes.items():
    plt.figure(figsize=(10, 3))
    plt.plot(df['x_axis'].rolling(roll_window).var(), label="x", alpha=0.7)
    plt.plot(df['y_axis'].rolling(roll_window).var(), label="y", alpha=0.7)
    plt.plot(df['z_axis'].rolling(roll_window).var(), label="z", alpha=0.7)
    plt.title(f"Rolling Variance - {name}")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Feature Extraction

# %%
# Segment into Windows
def segment_signal(df, window_size=100, step_size=100):
    """
    Split df into non-overlapping windows of length `window_size`.
    Returns segments: array(shape=(n_windows, 3, window_size))
            labels:   array(shape=(n_windows,))
            groups:   list of 'source' strings per window
    """
    segments, labels, groups = [], [], []
    for start in range(0, len(df) - window_size + 1, step_size):
        end = start + window_size
        x, y, z = df[['x_axis','y_axis','z_axis']].iloc[start:end].values.T
        segments.append([x, y, z])
        labels.append(df['class_label'].iloc[start])
        groups.append(df['source'].iloc[start])
    return np.array(segments), np.array(labels), np.array(groups)

# Apply per DataFrame
all_segments, all_labels, all_groups = [], [], []
for name, df in dataframes.items():
    segs, labs, grps = segment_signal(df, window_size=100, step_size=100)
    all_segments.append(segs)
    all_labels.append(labs)
    all_groups.append(grps)

# Concatenate across sources
segments_all = np.concatenate(all_segments, axis=0)
labels_all   = np.concatenate(all_labels, axis=0)
groups_all   = np.concatenate(all_groups, axis=0)

print("Segments:", segments_all.shape)
print("Labels:", labels_all.shape)
# Out:
# Segments: (40, 3, 100)
# Labels: (40,)

# %%
# Enhanced Feature Extraction
def extract_features_with_magnitude(segments, fft_bins=50, roll_win=10):
    """
    segments: array of shape (n_windows, 3, window_size)
    Returns: array of shape (n_windows, n_features)
    where n_features = 3_axes * (fft_bins*2/statistics) + magnitude features
    """
    feature_list = []
    for x, y, z in segments:
        # --- 1) Axis features (as before) ---
        def axis_feats(sig):
            # FFT
            fft_vals = np.abs(fft(sig))[:fft_bins]
            fft_mean, fft_std = fft_vals.mean(), fft_vals.std()
            # Time-domain stats
            m, s, mn, mx = sig.mean(), sig.std(), sig.min(), sig.max()
            sk, kt = skew(sig), kurtosis(sig)
            # Rolling variance
            rv = pd.Series(sig).rolling(roll_win).var().dropna()
            rv_mean, rv_std = rv.mean(), rv.std()
            return np.hstack([fft_vals, 
                              m, s, mn, mx, sk, kt, 
                              fft_mean, fft_std, 
                              rv_mean, rv_std])

        x_feats = axis_feats(x)
        y_feats = axis_feats(y)
        z_feats = axis_feats(z)

        # --- 2) Magnitude features ---
        acc = np.sqrt(x**2 + y**2 + z**2)
        # FFT on magnitude
        acc_fft = np.abs(fft(acc))[:fft_bins]
        acc_fft_mean, acc_fft_std = acc_fft.mean(), acc_fft.std()
        # Time-domain stats on magnitude
        acc_m, acc_s, acc_min, acc_max = acc.mean(), acc.std(), acc.min(), acc.max()
        acc_sk, acc_kt = skew(acc), kurtosis(acc)
        # Rolling variance on magnitude
        acc_rv = pd.Series(acc).rolling(roll_win).var().dropna()
        acc_rv_mean, acc_rv_std = acc_rv.mean(), acc_rv.std()

        mag_feats = np.hstack([
            acc_fft,
            acc_m, acc_s, acc_min, acc_max, acc_sk, acc_kt,
            acc_fft_mean, acc_fft_std,
            acc_rv_mean, acc_rv_std
        ])

        # --- 3) Concatenate all ---
        feature_list.append(np.hstack([x_feats, y_feats, z_feats, mag_feats]))

    return np.array(feature_list)

# %%
features_all = extract_features_with_magnitude(segments_all, fft_bins=50, roll_win=10)
print("New feature matrix shape:", features_all.shape)
 
#   3 * (50 FFT + 6 stats + 2 FFT-summaries + 2 rolling-summaries)
# + (50 FFT + 6 stats + 2 FFT-summaries + 2 rolling-summaries)
# = 3*(50+6+2+2) + (50+6+2+2) = 3*60 + 60 = 240 features per window.
# Out:
# New feature matrix shape: (40, 240)

# %% [markdown]
# ## Data Prep for ML

# %%
# Train/Test Split
# `features_all` (n_samples × n_features) and `labels_all` (n_samples,) come from your previous steps.

# 1) Stratify on labels to ensure each class in train & test
X_train, X_test, y_train, y_test = train_test_split(
    features_all, labels_all,
    test_size=0.2,
    stratify=labels_all,
    random_state=42
)

# 2) Scale AFTER splitting (fit on train only)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# 3) One-hot encode
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat  = to_categorical(y_test,  num_classes=4)

print("Train class counts:", np.bincount(y_train))
print("Test  class counts:", np.bincount(y_test))
# Out:
# Train class counts: [8 8 8 8]
# Test  class counts: [2 2 2 2]

# %%
# Scaling
scaler = StandardScaler().fit(X_train)  # fit on train only
X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# ## DNN

# %%
# Deep Neural Network
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr  = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

inp = Input(shape=(X_train_scaled.shape[1],))
x = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(inp)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(32, activation='relu', kernel_regularizer=l2(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(16, activation='relu', kernel_regularizer=l2(1e-4))(x)
out = Dense(4, activation='softmax')(x)

model = Model(inp, out)
model.compile(optimizer=Adam(1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 240)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        15,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,484 (72.20 KB)
#  Trainable params: 18,292 (71.45 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Training the model
history = model.fit(
    X_train_scaled, y_train_cat,
    validation_split = 0.2,
    epochs = 100,
    batch_size = 32,
    callbacks = [early_stop, reduce_lr],
    verbose = 2
)
# Out:
# Epoch 1/100
# 1/1 - 1s - 856ms/step - accuracy: 0.4000 - loss: 1.6542 - val_accuracy: 0.1429 - val_loss: 1.4913 - learning_rate: 0.0010
# Epoch 2/100
# 1/1 - 0s - 33ms/step - accuracy: 0.3600 - loss: 1.6948 - val_accuracy: 0.2857 - val_loss: 1.4281 - learning_rate: 0.0010
# Epoch 3/100
# 1/1 - 0s - 31ms/step - accuracy: 0.3200 - loss: 1.5797 - val_accuracy: 0.1429 - val_loss: 1.3918 - learning_rate: 0.0010
# Epoch 4/100
# 1/1 - 0s - 31ms/step - accuracy: 0.2400 - loss: 1.5759 - val_accuracy: 0.1429 - val_loss: 1.3497 - learning_rate: 0.0010
# Epoch 5/100
# 1/1 - 0s - 31ms/step - accuracy: 0.3600 - loss: 1.3952 - val_accuracy: 0.1429 - val_loss: 1.3120 - learning_rate: 0.0010
# Epoch 6/100
# 1/1 - 0s - 31ms/step - accuracy: 0.5200 - loss: 1.1721 - val_accuracy: 0.2857 - val_loss: 1.2819 - learning_rate: 0.0010
# Epoch 7/100
# 1/1 - 0s - 30ms/step - accuracy: 0.2800 - loss: 1.8488 - val_accuracy: 0.2857 - val_loss: 1.2583 - learning_rate: 0.0010
# Epoch 8/100
# 1/1 - 0s - 31ms/step - accuracy: 0.5200 - loss: 1.2302 - val_accuracy: 0.2857 - val_loss: 1.2396 - learning_rate: 0.0010
# Epoch 9/100
# 1/1 - 0s - 30ms/step - accuracy: 0.3600 - loss: 1.3064 - val_accuracy: 0.2857 - val_loss: 1.2217 - learning_rate: 0.0010
# Epoch 10/100
# 1/1 - 0s - 30ms/step - accuracy: 0.4800 - loss: 1.2066 - val_accuracy: 0.2857 - val_loss: 1.2047 - learning_rate: 0.0010
# Epoch 11/100
# 1/1 - 0s - 30ms/step - accuracy: 0.4800 - loss: 1.0564 - val_accuracy: 0.2857 - val_loss: 1.1878 - learning_rate: 0.0010
# Epoch 12/100
# 1/1 - 0s - 81ms/step - accuracy: 0.4800 - loss: 1.0772 - val_accuracy: 0.4286 - val_loss: 1.1706 - learning_rate: 0.0010
# Epoch 13/100
# 1/1 - 0s - 41ms/step - accuracy: 0.4400 - loss: 1.1891 - val_accuracy: 0.4286 - val_loss: 1.1569 - learning_rate: 0.0010
# Epoch 14/100
# 1/1 - 0s - 31ms/step - accuracy: 0.5600 - loss: 0.9236 - val_accuracy: 0.4286 - val_loss: 1.1437 - learning_rate: 0.0010
# Epoch 15/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6000 - loss: 0.6745 - val_accuracy: 0.4286 - val_loss: 1.1320 - learning_rate: 0.0010
# Epoch 16/100
# 1/1 - 0s - 31ms/step - accuracy: 0.5200 - loss: 1.0845 - val_accuracy: 0.4286 - val_loss: 1.1188 - learning_rate: 0.0010
# Epoch 17/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6000 - loss: 0.8461 - val_accuracy: 0.4286 - val_loss: 1.1065 - learning_rate: 0.0010
# Epoch 18/100
# 1/1 - 0s - 31ms/step - accuracy: 0.4400 - loss: 1.0458 - val_accuracy: 0.4286 - val_loss: 1.0931 - learning_rate: 0.0010
# Epoch 19/100
# 1/1 - 0s - 31ms/step - accuracy: 0.5600 - loss: 1.0196 - val_accuracy: 0.4286 - val_loss: 1.0810 - learning_rate: 0.0010
# Epoch 20/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6800 - loss: 0.8132 - val_accuracy: 0.4286 - val_loss: 1.0692 - learning_rate: 0.0010
# Epoch 21/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6400 - loss: 0.7297 - val_accuracy: 0.4286 - val_loss: 1.0567 - learning_rate: 0.0010
# Epoch 22/100
# 1/1 - 0s - 31ms/step - accuracy: 0.7600 - loss: 0.6800 - val_accuracy: 0.4286 - val_loss: 1.0471 - learning_rate: 0.0010
# Epoch 23/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6000 - loss: 0.9636 - val_accuracy: 0.4286 - val_loss: 1.0360 - learning_rate: 0.0010
# Epoch 24/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6800 - loss: 0.7852 - val_accuracy: 0.4286 - val_loss: 1.0260 - learning_rate: 0.0010
# Epoch 25/100
# 1/1 - 0s - 31ms/step - accuracy: 0.7600 - loss: 0.6916 - val_accuracy: 0.5714 - val_loss: 1.0150 - learning_rate: 0.0010
# Epoch 26/100
# 1/1 - 0s - 30ms/step - accuracy: 0.5600 - loss: 0.9838 - val_accuracy: 0.5714 - val_loss: 1.0048 - learning_rate: 0.0010
# Epoch 27/100
# 1/1 - 0s - 30ms/step - accuracy: 0.7600 - loss: 0.6261 - val_accuracy: 0.5714 - val_loss: 0.9919 - learning_rate: 0.0010
# Epoch 28/100
# 1/1 - 0s - 30ms/step - accuracy: 0.7200 - loss: 0.6689 - val_accuracy: 0.5714 - val_loss: 0.9804 - learning_rate: 0.0010
# Epoch 29/100
# 1/1 - 0s - 30ms/step - accuracy: 0.6800 - loss: 0.6747 - val_accuracy: 0.5714 - val_loss: 0.9691 - learning_rate: 0.0010
# Epoch 30/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6800 - loss: 0.7510 - val_accuracy: 0.5714 - val_loss: 0.9584 - learning_rate: 0.0010
# Epoch 31/100
# 1/1 - 0s - 32ms/step - accuracy: 0.6800 - loss: 0.6472 - val_accuracy: 0.5714 - val_loss: 0.9458 - learning_rate: 0.0010
# Epoch 32/100
# 1/1 - 0s - 35ms/step - accuracy: 0.7600 - loss: 0.6234 - val_accuracy: 0.7143 - val_loss: 0.9345 - learning_rate: 0.0010
# Epoch 33/100
# 1/1 - 0s - 32ms/step - accuracy: 0.8400 - loss: 0.5302 - val_accuracy: 0.7143 - val_loss: 0.9236 - learning_rate: 0.0010
# Epoch 34/100
# 1/1 - 0s - 31ms/step - accuracy: 0.6800 - loss: 0.7305 - val_accuracy: 0.7143 - val_loss: 0.9133 - learning_rate: 0.0010
# Epoch 35/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8800 - loss: 0.5000 - val_accuracy: 0.7143 - val_loss: 0.9024 - learning_rate: 0.0010
# Epoch 36/100
# 1/1 - 0s - 34ms/step - accuracy: 0.7600 - loss: 0.6045 - val_accuracy: 0.7143 - val_loss: 0.8919 - learning_rate: 0.0010
# Epoch 37/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8400 - loss: 0.5369 - val_accuracy: 0.7143 - val_loss: 0.8795 - learning_rate: 0.0010
# Epoch 38/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8000 - loss: 0.6953 - val_accuracy: 0.7143 - val_loss: 0.8692 - learning_rate: 0.0010
# Epoch 39/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8400 - loss: 0.5058 - val_accuracy: 0.7143 - val_loss: 0.8587 - learning_rate: 0.0010
# Epoch 40/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8000 - loss: 0.5271 - val_accuracy: 0.7143 - val_loss: 0.8479 - learning_rate: 0.0010
# Epoch 41/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8400 - loss: 0.5244 - val_accuracy: 0.7143 - val_loss: 0.8364 - learning_rate: 0.0010
# Epoch 42/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8800 - loss: 0.4972 - val_accuracy: 0.7143 - val_loss: 0.8252 - learning_rate: 0.0010
# Epoch 43/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.4066 - val_accuracy: 0.7143 - val_loss: 0.8147 - learning_rate: 0.0010
# Epoch 44/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8800 - loss: 0.4401 - val_accuracy: 0.7143 - val_loss: 0.8037 - learning_rate: 0.0010
# Epoch 45/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8400 - loss: 0.4562 - val_accuracy: 0.7143 - val_loss: 0.7922 - learning_rate: 0.0010
# Epoch 46/100
# 1/1 - 0s - 30ms/step - accuracy: 0.8400 - loss: 0.4986 - val_accuracy: 0.7143 - val_loss: 0.7805 - learning_rate: 0.0010
# Epoch 47/100
# 1/1 - 0s - 33ms/step - accuracy: 0.8400 - loss: 0.5562 - val_accuracy: 0.7143 - val_loss: 0.7700 - learning_rate: 0.0010
# Epoch 48/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9200 - loss: 0.3854 - val_accuracy: 0.7143 - val_loss: 0.7588 - learning_rate: 0.0010
# Epoch 49/100
# 1/1 - 0s - 33ms/step - accuracy: 0.9600 - loss: 0.3765 - val_accuracy: 0.7143 - val_loss: 0.7485 - learning_rate: 0.0010
# Epoch 50/100
# 1/1 - 0s - 33ms/step - accuracy: 0.8400 - loss: 0.5397 - val_accuracy: 0.7143 - val_loss: 0.7389 - learning_rate: 0.0010
# Epoch 51/100
# 1/1 - 0s - 32ms/step - accuracy: 0.9600 - loss: 0.3230 - val_accuracy: 0.7143 - val_loss: 0.7284 - learning_rate: 0.0010
# Epoch 52/100
# 1/1 - 0s - 33ms/step - accuracy: 0.8000 - loss: 0.4041 - val_accuracy: 0.7143 - val_loss: 0.7187 - learning_rate: 0.0010
# Epoch 53/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8400 - loss: 0.5575 - val_accuracy: 0.7143 - val_loss: 0.7097 - learning_rate: 0.0010
# Epoch 54/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.3438 - val_accuracy: 0.7143 - val_loss: 0.6995 - learning_rate: 0.0010
# Epoch 55/100
# 1/1 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3019 - val_accuracy: 0.7143 - val_loss: 0.6902 - learning_rate: 0.0010
# Epoch 56/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9600 - loss: 0.3033 - val_accuracy: 0.7143 - val_loss: 0.6816 - learning_rate: 0.0010
# Epoch 57/100
# 1/1 - 0s - 30ms/step - accuracy: 0.8400 - loss: 0.3877 - val_accuracy: 0.7143 - val_loss: 0.6732 - learning_rate: 0.0010
# Epoch 58/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9200 - loss: 0.3621 - val_accuracy: 0.7143 - val_loss: 0.6641 - learning_rate: 0.0010
# Epoch 59/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9200 - loss: 0.3766 - val_accuracy: 0.7143 - val_loss: 0.6543 - learning_rate: 0.0010
# Epoch 60/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.3307 - val_accuracy: 0.7143 - val_loss: 0.6452 - learning_rate: 0.0010
# Epoch 61/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.3532 - val_accuracy: 0.7143 - val_loss: 0.6349 - learning_rate: 0.0010
# Epoch 62/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2843 - val_accuracy: 0.7143 - val_loss: 0.6242 - learning_rate: 0.0010
# Epoch 63/100
# 1/1 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.2522 - val_accuracy: 0.7143 - val_loss: 0.6120 - learning_rate: 0.0010
# Epoch 64/100
# 1/1 - 0s - 30ms/step - accuracy: 0.8800 - loss: 0.3890 - val_accuracy: 0.7143 - val_loss: 0.6011 - learning_rate: 0.0010
# Epoch 65/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9600 - loss: 0.2543 - val_accuracy: 0.7143 - val_loss: 0.5901 - learning_rate: 0.0010
# Epoch 66/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.4048 - val_accuracy: 0.7143 - val_loss: 0.5787 - learning_rate: 0.0010
# Epoch 67/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2024 - val_accuracy: 0.8571 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 68/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.3483 - val_accuracy: 0.8571 - val_loss: 0.5562 - learning_rate: 0.0010
# Epoch 69/100
# 1/1 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.2757 - val_accuracy: 0.8571 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 70/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.3028 - val_accuracy: 0.8571 - val_loss: 0.5342 - learning_rate: 0.0010
# Epoch 71/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.2993 - val_accuracy: 0.8571 - val_loss: 0.5235 - learning_rate: 0.0010
# Epoch 72/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2384 - val_accuracy: 0.8571 - val_loss: 0.5132 - learning_rate: 0.0010
# Epoch 73/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.2829 - val_accuracy: 0.8571 - val_loss: 0.5025 - learning_rate: 0.0010
# Epoch 74/100
# 1/1 - 0s - 31ms/step - accuracy: 0.8800 - loss: 0.3506 - val_accuracy: 0.8571 - val_loss: 0.4918 - learning_rate: 0.0010
# Epoch 75/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.3075 - val_accuracy: 0.8571 - val_loss: 0.4817 - learning_rate: 0.0010
# Epoch 76/100
# 1/1 - 0s - 30ms/step - accuracy: 0.9200 - loss: 0.2981 - val_accuracy: 0.8571 - val_loss: 0.4692 - learning_rate: 0.0010
# Epoch 77/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.1498 - val_accuracy: 0.8571 - val_loss: 0.4570 - learning_rate: 0.0010
# Epoch 78/100
# 1/1 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.2518 - val_accuracy: 1.0000 - val_loss: 0.4452 - learning_rate: 0.0010
# Epoch 79/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2954 - val_accuracy: 1.0000 - val_loss: 0.4332 - learning_rate: 0.0010
# Epoch 80/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.3261 - val_accuracy: 1.0000 - val_loss: 0.4214 - learning_rate: 0.0010
# Epoch 81/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2001 - val_accuracy: 1.0000 - val_loss: 0.4095 - learning_rate: 0.0010
# Epoch 82/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2399 - val_accuracy: 1.0000 - val_loss: 0.3989 - learning_rate: 0.0010
# Epoch 83/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2022 - val_accuracy: 1.0000 - val_loss: 0.3879 - learning_rate: 0.0010
# Epoch 84/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2573 - val_accuracy: 1.0000 - val_loss: 0.3770 - learning_rate: 0.0010
# Epoch 85/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2971 - val_accuracy: 1.0000 - val_loss: 0.3658 - learning_rate: 0.0010
# Epoch 86/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2124 - val_accuracy: 1.0000 - val_loss: 0.3548 - learning_rate: 0.0010
# Epoch 87/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9200 - loss: 0.3460 - val_accuracy: 1.0000 - val_loss: 0.3445 - learning_rate: 0.0010
# Epoch 88/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2017 - val_accuracy: 1.0000 - val_loss: 0.3346 - learning_rate: 0.0010
# Epoch 89/100
# 1/1 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.1636 - val_accuracy: 1.0000 - val_loss: 0.3244 - learning_rate: 0.0010
# Epoch 90/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.1870 - val_accuracy: 1.0000 - val_loss: 0.3145 - learning_rate: 0.0010
# Epoch 91/100
# 1/1 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.2190 - val_accuracy: 1.0000 - val_loss: 0.3051 - learning_rate: 0.0010
# Epoch 92/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2053 - val_accuracy: 1.0000 - val_loss: 0.2961 - learning_rate: 0.0010
# Epoch 93/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2554 - val_accuracy: 1.0000 - val_loss: 0.2874 - learning_rate: 0.0010
# Epoch 94/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2244 - val_accuracy: 1.0000 - val_loss: 0.2802 - learning_rate: 0.0010
# Epoch 95/100
# 1/1 - 0s - 32ms/step - accuracy: 0.9600 - loss: 0.3243 - val_accuracy: 1.0000 - val_loss: 0.2723 - learning_rate: 0.0010
# Epoch 96/100
# 1/1 - 0s - 35ms/step - accuracy: 0.9600 - loss: 0.2115 - val_accuracy: 1.0000 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 97/100
# 1/1 - 0s - 31ms/step - accuracy: 0.9600 - loss: 0.2389 - val_accuracy: 1.0000 - val_loss: 0.2559 - learning_rate: 0.0010
# Epoch 98/100
# 1/1 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.2192 - val_accuracy: 1.0000 - val_loss: 0.2481 - learning_rate: 0.0010
# Epoch 99/100
# 1/1 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.2179 - val_accuracy: 1.0000 - val_loss: 0.2406 - learning_rate: 0.0010
# Epoch 100/100
# 1/1 - 0s - 38ms/step - accuracy: 0.9600 - loss: 0.1998 - val_accuracy: 1.0000 - val_loss: 0.2330 - learning_rate: 0.0010

# %% [markdown]
# ## Model Evaluation

# %%
plt.figure(figsize=(12,4))
# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.legend(); plt.title('Learning Curve: Loss')

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch'); plt.ylabel('Accuracy')
plt.legend(); plt.title('Learning Curve: Accuracy')
plt.show()

# %%
gkf = GroupKFold(n_splits = 4)
val_scores = []

for train_idx, val_idx in gkf.split(features_all, labels_all, groups_all):
    # split
    X_tr, X_val = features_all[train_idx], features_all[val_idx]
    y_tr, y_val = labels_all[train_idx], labels_all[val_idx]
    # scale
    scaler = StandardScaler().fit(X_tr)
    X_tr_s = scaler.transform(X_tr)
    X_val_s = scaler.transform(X_val)
    # one-hot encode
    y_tr_c = to_categorical(y_tr, 4)
    y_val_c = to_categorical(y_val, 4)
    # clone & compile fresh model
    m = clone_model(model)
    m.set_weights(model.get_weights())  # optional: same initialization
    m.compile(optimizer=Adam(1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
    # train
    m.fit(
        X_tr_s, y_tr_c,
        validation_data=(X_val_s, y_val_c),
        epochs=20, batch_size=32,
        callbacks=[early_stop],
        verbose=0
    )
    # evaluate
    val_scores.append(m.evaluate(X_val_s, y_val_c, verbose=0)[1])

print("GroupKFold Validation accuracies:", np.round(val_scores, 3))
print("Mean ± Std:", np.mean(val_scores), "±", np.std(val_scores))
# Out:
# GroupKFold Validation accuracies: [1. 1. 1. 1.]
# Mean ± Std: 1.0 ± 0.0

# %%
# Binarize test labels
y_test_bin = label_binarize(y_test, classes=[0,1,2,3])
y_pred_proba = model.predict(X_test_scaled)

# Plot ROC curves
plt.figure(figsize=(12,5))
for i in range(4):
    fpr, tpr, _ = roc_curve(y_test_bin[:,i], y_pred_proba[:,i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC={roc_auc:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('FPR'); plt.ylabel('TPR')
plt.title('One-vs-Rest ROC Curves'); plt.legend()
plt.show()

# Plot PR curves
plt.figure(figsize=(12,5))
for i in range(4):
    prec, rec, _ = precision_recall_curve(y_test_bin[:,i], y_pred_proba[:,i])
    plt.plot(rec, prec, label=f'Class {i}')
plt.xlabel('Recall'); plt.ylabel('Precision')
plt.title('Precision-Recall Curves'); plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
# Evaluation
# Test set performance

test_loss, test_acc = model.evaluate(X_test_scaled, y_test_cat, verbose=0)
print(f"\nHold-out Test Accuracy: {test_acc:.4f}")

y_pred = model.predict(X_test_scaled)
y_pred_lbl = y_pred.argmax(axis=1)

# 7) Confusion Matrix & Classification Report
cm = confusion_matrix(y_test, y_pred_lbl)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[0,1,2,3], yticklabels=[0,1,2,3])
plt.xlabel("Predicted"); plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

print("\nClassification Report:")
print(classification_report(y_test, y_pred_lbl, zero_division=0))
# Out:
# Hold-out Test Accuracy: 1.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %% [markdown]
# ## Porting the model to TensorFlow Lite

# %%
#import tensorflow as tf

# Convert to TFLite
#converter = tf.lite.TFLiteConverter.from_keras_model(model)
#converter.optimizations = [tf.lite.Optimize.DEFAULT]  # enable default optimizations (quantization)
#tflite_model = converter.convert()

# Save
#with open('model_quant.tflite', 'wb') as f:
#    f.write(tflite_model)

# Report size
#import os
#size_kb = os.path.getsize('model_quant.tflite') / 1024
#print(f"Quantized TFLite model size: {size_kb:.1f} KB")

# %% [markdown]
# ## Sanity Check

# %%
# PCA + Logistic Regression Baseline
import pandas as pd
import numpy as np
from scipy.fft import fft
from scipy.stats import skew, kurtosis
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold
import matplotlib.pyplot as plt

# 1) Reload & re-segment (non-overlap)
files = {
    "motor_OFF": "motor_OFF.xlsx",
    "motor_ON": "motor_ON.xlsx",
    "motor_ON_NO_FAN": "motor_ON_NO_fan.xlsx",
    "motor_ON_BAD_FAN": "motor_ON_BAD_FAN.xlsx"
}

dataframes = {label: pd.read_excel(path) for label, path in files.items()}

def segment_signal(df, window_size=100, step_size=100):
    segs, labs = [], []
    for start in range(0, len(df) - window_size + 1, step_size):
        seg = df[['x_axis','y_axis','z_axis']].iloc[start:start+window_size].values.T
        segs.append(seg)
        labs.append(df['class_label'].iloc[start])
    return np.array(segs), np.array(labs)

# gather all segments and labels
segments_list, labels_list = [], []
for df in dataframes.values():
    s, l = segment_signal(df)
    segments_list.append(s)
    labels_list.append(l)
segments_all = np.concatenate(segments_list, axis=0)
labels_all   = np.concatenate(labels_list, axis=0)

# 2) Feature extraction (including vector magnitude)
def extract_features_with_magnitude(segs, fft_bins=50, roll_win=10):
    feats = []
    for x, y, z in segs:
        def axis_feats(sig):
            vals = np.abs(fft(sig))[:fft_bins]
            m, s, mn, mx = sig.mean(), sig.std(), sig.min(), sig.max()
            sk, kt = skew(sig), kurtosis(sig)
            rv = pd.Series(sig).rolling(roll_win).var().dropna()
            rv_m, rv_s = rv.mean(), rv.std()
            return np.hstack([vals, m, s, mn, mx, sk, kt, vals.mean(), vals.std(), rv_m, rv_s])
        x_f, y_f, z_f = axis_feats(x), axis_feats(y), axis_feats(z)
        acc = np.sqrt(x**2 + y**2 + z**2)
        a_vals = np.abs(fft(acc))[:fft_bins]
        a_stats = [acc.mean(), acc.std(), acc.min(), acc.max(), skew(acc), kurtosis(acc)]
        a_rv = pd.Series(acc).rolling(roll_win).var().dropna()
        a_feats = np.hstack([a_vals, *a_stats, a_vals.mean(), a_vals.std(), a_rv.mean(), a_rv.std()])
        feats.append(np.hstack([x_f, y_f, z_f, a_feats]))
    return np.array(feats)

features_all = extract_features_with_magnitude(segments_all)

# 3) PCA to 10 components for modeling
pca = PCA(n_components=10, random_state=42)
X_pca = pca.fit_transform(features_all)

# 4) Logistic Regression with 5-fold Stratified CV
clf = LogisticRegression(max_iter=1000, random_state=42)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(clf, X_pca, labels_all, cv=cv, scoring='accuracy')
print(f"CV Accuracy: {scores.mean():.3f} ± {scores.std():.3f}")

# 5) PCA to 2 components for scatter plot
pca2 = PCA(n_components=2, random_state=42)
X_vis = pca2.fit_transform(features_all)
df_vis = pd.DataFrame(X_vis, columns=['PC1','PC2'])
df_vis['label'] = labels_all

plt.figure(figsize=(6,5))
for lbl in sorted(df_vis['label'].unique()):
    subset = df_vis[df_vis['label']==lbl]
    plt.scatter(subset['PC1'], subset['PC2'], label=f'Class {lbl}', alpha=0.8)
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.title('2D PCA of Vibration Windows')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# CV Accuracy: 1.000 ± 0.000
